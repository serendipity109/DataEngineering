# %%
import dask.array as da
from dask.distributed import Client

# %%
x = da.random.random((50000, 50000), chunks=(10000, 10000))

y = da.exp(x).mean()

# %%
client = Client("tcp://127.0.0.1:8786")

result = y.compute()
print(result)
# Out:
# 1.7182735526561397
# 2025-04-25 00:24:16,837 - distributed.client - ERROR - Failed to reconnect to scheduler after 30.00 seconds, closing client
